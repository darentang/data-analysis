# %%
import pandas as pd

therapeutic = pd.read_csv("data/Pain Therapeutic result.txt", sep="\t")
placebo = pd.read_csv("data/Pain Placebo result.txt", sep="\t")
therapeutic["name"] = therapeutic.name.str.rstrip()
placebo["name"] = placebo.name.str.rstrip()
therapeutic = therapeutic.set_index("name").sort_index()
placebo = placebo.set_index("name").sort_index()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/78/4ns7k92d3cngfnncjf23cg340000gn/T/ipykernel_98924/1669924604.py in <module>
#       3 therapeutic = pd.read_csv("data/Pain Therapeutic result.txt", sep="\t")
#       4 placebo = pd.read_csv("data/Pain Placebo result.txt", sep="\t")
# ----> 5 therapeutic["name"] = therapeutic.name.str.rstrip()
#       6 placebo["name"] = placebo.name.str.rstrip()
#       7 therapeutic = therapeutic.set_index("name").sort_index()
#
# ~/thesis/thesis/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# ~/thesis/thesis/lib/python3.9/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     179             # we're accessing the attribute of the class, i.e., Dataset.geo
#     180             return self._accessor
# --> 181         accessor_obj = self._accessor(obj)
#     182         # Replace the property with the accessor object. Inspired by:
#     183         # https://www.pydanny.com/cached-property.html
#
# ~/thesis/thesis/lib/python3.9/site-packages/pandas/core/strings/accessor.py in __init__(self, data)
#     166         from pandas.core.arrays.string_ import StringDtype
#     167
# --> 168         self._inferred_dtype = self._validate(data)
#     169         self._is_categorical = is_categorical_dtype(data.dtype)
#     170         self._is_string = isinstance(data.dtype, StringDtype)
#
# ~/thesis/thesis/lib/python3.9/site-packages/pandas/core/strings/accessor.py in _validate(data)
#     223
#     224         if inferred_dtype not in allowed_types:
# --> 225             raise AttributeError("Can only use .str accessor with string values!")
#     226         return inferred_dtype
#     227
#
# AttributeError: Can only use .str accessor with string values!

# %%
sizes = pd.read_csv("sizes.txt", sep="\t")
sizes["group"] = ["placebo" if "Placebo" in x else "therapeutic" for x in sizes.subgroup]
sizes["name"] = [" ".join(x.split()[:2]) for x in sizes.name]
sizes = sizes.set_index("name").sort_index()
sizes
# Out:
#                                     subgroup  pre  pos        group
# name
# Akbarnezhad 2019      Manual therapy Placebo   14   14      placebo
# Akbarnezhad 2019  Manual therapy Therapeutic   14   14  therapeutic
# Alkhawajah 2019       Manual therapy Placebo   20   20      placebo
# Alkhawajah 2019   Manual therapy Therapeutic   20   20  therapeutic
# Anandkumar 2014               Taping Placebo   20   20      placebo
# ...                                      ...  ...  ...          ...
# Toda 2005          Foot orthosis Therapeutic   21   21  therapeutic
# Toda 2008              Foot orthosis Placebo   38   38      placebo
# Toda 2008          Foot orthosis Therapeutic   43   43  therapeutic
# Wageck 2016                   Taping Placebo   38   36      placebo
# Wageck 2016               Taping Therapeutic   38   36  therapeutic
#
# [74 rows x 4 columns]

# %%
sizes.query("group == 'therapeutic'").index == therapeutic.index
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True])

# %%
placebo["n"] = sizes.query("group == 'placebo'").pos
therapeutic["n"] = sizes.query("group == 'therapeutic'").pos

placebo
# Out:
#                                        subgroup        mu        se     sigma  \
# name
# Akbarnezhad 2019                 Manual therapy  0.695269  0.297813  0.088693
# Alkhawajah 2019                  Manual therapy  0.585018  0.241984  0.058556
# Anandkumar 2014                          Taping  0.159617  0.225027  0.050637
# Bar-Ziv 2010                      Foot orthosis -0.148148  0.280494  0.078677
# Barrios 2009                      Foot orthosis  0.390897  0.186340  0.034723
# Bennell 2005           Multimodal physiotherapy  0.818345  0.141149  0.019923
# Bennell 2011                      Foot orthosis  0.326686  0.104208  0.010859
# Bennell 2013                      Foot orthosis  1.864870  0.625513  0.391267
# ChoH-Y 2015                              Taping  0.139850  0.209531  0.043903
# Cudejko 2017                              Brace  0.225926  0.152667  0.023307
# Deyle 2000             Multimodal physiotherapy  0.323293  0.170966  0.029229
# Donec 2020                               Taping  0.485307  0.156867  0.024607
# Erhart 2010                       Foot orthosis  0.284007  0.200032  0.040013
# Foroughi 2011                          Exercise  0.345118  0.205869  0.042382
# Hatef 2014                        Foot orthosis  0.507353  0.136027  0.018503
# Hayati 2019                              Taping  1.129034  0.301728  0.091040
# Hinman 2003                              Taping  0.485728  0.196343  0.038551
# Hinman 2016                       Foot orthosis  0.604070  0.161180  0.025979
# Hjartarson 2018                           Brace  0.242996  0.207403  0.043016
# Hunter 2011                               Brace  0.469977  0.168739  0.028473
# Hunter 2012                               Brace  0.011031  0.158119  0.025002
# Kocyigit 2015                            Taping  0.657777  0.246611  0.060817
# Leon-Ballesteros 2020                    Taping  1.423077  0.354663  0.125786
# Mutlu 2017                               Taping  0.931480  0.274708  0.075465
# Ogut 2018                                Taping  4.109975  0.561128  0.314865
# Pham 2004                         Foot orthosis  0.213940  0.117570  0.013823
# Pinherio 2020                            Taping  0.523810  0.275341  0.075813
# Pollard 2008                     Manual therapy  0.169769  0.244277  0.059671
# Rahlf 2019                               Taping  0.015802  0.145874  0.021279
# Reichenbach 2020                  Foot orthosis  0.700000  0.106874  0.011422
# Rodrigues 2008                    Foot orthosis  0.188579  0.269627  0.072699
# Tan 2019                          Foot orthosis  0.731927  0.339499  0.115260
# Tan 2020                          Foot orthosis  0.077270  0.447881  0.200597
# Tanaka 2018                      Manual therapy  0.458831  0.262829  0.069079
# Toda 2005                         Foot orthosis  0.459431  0.224169  0.050252
# Toda 2008                         Foot orthosis  0.126098  0.162865  0.026525
# Wageck 2016                              Taping  0.750000  0.240612  0.057894
#
#                              lb        ub         z             p    n
# name
# Akbarnezhad 2019       0.111566  1.278973  2.334580  1.956538e-02   14
# Alkhawajah 2019        0.110739  1.059298  2.417592  1.562359e-02   20
# Anandkumar 2014       -0.281427  0.600661  0.709327  4.781216e-01   20
# Bar-Ziv 2010          -0.697906  0.401609 -0.528169  5.973819e-01   25
# Barrios 2009           0.025677  0.756116  2.097761  3.592623e-02   31
# Bennell 2005           0.541698  1.094992  5.797739  6.721487e-09   67
# Bennell 2011           0.122441  0.530931  3.134926  1.718975e-03   97
# Bennell 2013           0.638886  3.090854  2.981342  2.869878e-03    7
# ChoH-Y 2015           -0.270824  0.550524  0.667441  5.044905e-01   23
# Cudejko 2017          -0.073296  0.525148  1.479858  1.389111e-01   44
# Deyle 2000            -0.011795  0.658380  1.890975  5.862769e-02   36
# Donec 2020             0.177852  0.792761  3.093737  1.976526e-03   76
# Erhart 2010           -0.108048  0.676062  1.419808  1.556636e-01   26
# Foroughi 2011         -0.058378  0.748615  1.676396  9.366060e-02   25
# Hatef 2014             0.240745  0.773961  3.729798  1.916331e-04   61
# Hayati 2019            0.537657  1.720411  3.741889  1.826421e-04   19
# Hinman 2003            0.100903  0.870553  2.473874  1.336570e-02   29
# Hinman 2016            0.288164  0.919977  3.747805  1.783887e-04   80
# Hjartarson 2018       -0.163506  0.649498  1.171615  2.413519e-01   34
# Hunter 2011            0.139255  0.800699  2.785232  5.348939e-03   39
# Hunter 2012           -0.298876  0.320938  0.069765  9.443805e-01   40
# Kocyigit 2015          0.174430  1.141125  2.667272  7.646986e-03   20
# Leon-Ballesteros 2020  0.727950  2.118204  4.012476  6.008520e-05   16
# Mutlu 2017             0.393062  1.469898  3.390798  6.968945e-04   19
# Ogut 2018              3.010184  5.209766  7.324484  2.398082e-13   30
# Pham 2004             -0.016493  0.444374  1.819681  6.880756e-02   74
# Pinherio 2020         -0.015848  1.063468  1.902404  5.711830e-02   15
# Pollard 2008          -0.309005  0.648543  0.694986  4.870638e-01   17
# Rahlf 2019            -0.270106  0.301710  0.108327  9.137366e-01   47
# Reichenbach 2020       0.490531  0.909469  6.549778  5.762257e-11  109
# Rodrigues 2008        -0.339880  0.717037  0.699406  4.842985e-01   14
# Tan 2019               0.066521  1.397334  2.155901  3.109138e-02   11
# Tan 2020              -0.800560  0.955100  0.172523  8.630260e-01    5
# Tanaka 2018           -0.056303  0.973966  1.745743  8.085560e-02   16
# Toda 2005              0.020068  0.898795  2.049486  4.041458e-02   22
# Toda 2008             -0.193112  0.445307  0.774247  4.387845e-01   38
# Wageck 2016            0.278409  1.221591  3.117049  1.826715e-03   36

# %%
therapeutic.mu
# Out:
# name
# Akbarnezhad 2019         3.208869
# Alkhawajah 2019          3.159097
# Anandkumar 2014          1.979487
# Bar-Ziv 2010             1.564223
# Barrios 2009             0.508387
# Bennell 2005             0.699953
# Bennell 2011             0.221470
# Bennell 2013             1.628112
# ChoH-Y 2015              2.026617
# Cudejko 2017             0.213151
# Deyle 2000               1.367880
# Donec 2020               0.565758
# Erhart 2010              0.575607
# Foroughi 2011            0.603701
# Hatef 2014               1.844445
# Hayati 2019              1.990757
# Hinman 2003              0.564725
# Hinman 2016              0.766564
# Hjartarson 2018          0.729621
# Hunter 2011              0.157338
# Hunter 2012              0.105409
# Kocyigit 2015            0.428571
# Leon-Ballesteros 2020    0.832050
# Mutlu 2017               1.077497
# Ogut 2018                4.205955
# Pham 2004                0.106796
# Pinherio 2020            0.568177
# Pollard 2008             0.862322
# Rahlf 2019               0.085088
# Reichenbach 2020         1.864109
# Rodrigues 2008           1.857143
# Tan 2019                 1.335135
# Tan 2020                 1.616296
# Tanaka 2018              0.986666
# Toda 2005                0.918388
# Toda 2008                0.124551
# Wageck 2016              0.851847
# Name: mu, dtype: float64

# %%
import numpy as np
data = pd.DataFrame()

data["L"] = np.log(np.clip(placebo.mu / therapeutic.mu, -1, 1))
data["v"] = placebo.sigma/placebo.n/placebo.mu**2 + therapeutic.sigma/therapeutic.n/therapeutic.mu**2
data["w"] = 1 / data.v
data["subgroup"] = placebo.subgroup
data = data.dropna()
data
# Out:
# /Users/tang.dar.en/thesis/thesis/lib/python3.9/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#                               L         v            w  \
# name
# Akbarnezhad 2019      -1.529375  0.016152    61.911667
# Alkhawajah 2019       -1.686399  0.010055    99.451135
# Anandkumar 2014       -2.517813  0.101263     9.875273
# Barrios 2009          -0.262799  0.010897    91.768396
# Bennell 2005           0.000000  0.000921  1085.933205
# Bennell 2011           0.000000  0.003018   331.359876
# Bennell 2013           0.000000  0.051162    19.545607
# ChoH-Y 2015           -2.673554  0.099005    10.100533
# Cudejko 2017           0.000000  0.022005    45.444175
# Deyle 2000            -1.442460  0.008718   114.702526
# Donec 2020            -0.153386  0.002297   435.443303
# Erhart 2010           -0.706428  0.022123    45.201942
# Foroughi 2011         -0.559191  0.022343    44.756945
# Hatef 2014            -1.290726  0.001423   702.847029
# Hayati 2019           -0.567153  0.004310   232.009016
# Hinman 2003           -0.150690  0.009957   100.427918
# Hinman 2016           -0.238228  0.001450   689.432539
# Hjartarson 2018       -1.099479  0.022686    44.080628
# Hunter 2011            0.000000  0.027633    36.187961
# Hunter 2012           -2.257123  5.192986     0.192567
# Kocyigit 2015          0.000000  0.020508    48.762583
# Leon-Ballesteros 2020  0.000000  0.011477    87.127120
# Mutlu 2017            -0.145621  0.007981   125.298082
# Ogut 2018             -0.023085  0.001200   833.022533
# Pham 2004              0.000000  0.017195    58.156158
# Pinherio 2020         -0.081304  0.034410    29.061190
# Pollard 2008          -1.625190  0.124515     8.031142
# Rahlf 2019            -1.683546  1.875897     0.533078
# Reichenbach 2020      -0.979458  0.000278  3599.799640
# Rodrigues 2008        -2.287280  0.149106     6.706633
# Tan 2019              -0.601107  0.026927    37.137349
# Tan 2020              -3.040588  6.733244     0.148517
# Tanaka 2018           -0.765649  0.026473    37.773651
# Toda 2005             -0.692631  0.014644    68.288410
# Toda 2008              0.000000  0.079033    12.652947
# Wageck 2016           -0.127334  0.005117   195.412724
#
#                                        subgroup
# name
# Akbarnezhad 2019                 Manual therapy
# Alkhawajah 2019                  Manual therapy
# Anandkumar 2014                          Taping
# Barrios 2009                      Foot orthosis
# Bennell 2005           Multimodal physiotherapy
# Bennell 2011                      Foot orthosis
# Bennell 2013                      Foot orthosis
# ChoH-Y 2015                              Taping
# Cudejko 2017                              Brace
# Deyle 2000             Multimodal physiotherapy
# Donec 2020                               Taping
# Erhart 2010                       Foot orthosis
# Foroughi 2011                          Exercise
# Hatef 2014                        Foot orthosis
# Hayati 2019                              Taping
# Hinman 2003                              Taping
# Hinman 2016                       Foot orthosis
# Hjartarson 2018                           Brace
# Hunter 2011                               Brace
# Hunter 2012                               Brace
# Kocyigit 2015                            Taping
# Leon-Ballesteros 2020                    Taping
# Mutlu 2017                               Taping
# Ogut 2018                                Taping
# Pham 2004                         Foot orthosis
# Pinherio 2020                            Taping
# Pollard 2008                     Manual therapy
# Rahlf 2019                               Taping
# Reichenbach 2020                  Foot orthosis
# Rodrigues 2008                    Foot orthosis
# Tan 2019                          Foot orthosis
# Tan 2020                          Foot orthosis
# Tanaka 2018                      Manual therapy
# Toda 2005                         Foot orthosis
# Toda 2008                         Foot orthosis
# Wageck 2016                              Taping

# %%
from scipy.stats import norm

def calc_ratio(data):
    k = len(data)
    if k < 3:
        return 0, 0, 0
    Q = np.sum(data.w * data.L**2) - np.sum(data.w*data.L)**2/np.sum(data.w)
    var_lambda = (Q - (k-1) )/(np.sum(data.w) - np.sum(data.w**2)/np.sum(data.w))

    w_star = 1/(data.v + var_lambda)
    mu_lambda = np.sum(w_star * data.L) / np.sum(w_star)
    se_L = np.sqrt(1 / np.sum(w_star))

    z_alpha = - norm.ppf(0.05/2)
    lb = mu_lambda - z_alpha * se_L
    ub = mu_lambda + z_alpha * se_L

    mu_rho = np.exp(mu_lambda)
    lb_rho = np.exp(lb)
    ub_rho = np.exp(ub)

    return mu_rho, lb_rho, ub_rho

# %%
def format_result(group, mu, lb, ub):
    if mu == 0:
        print(f"{group} is too small.")
        return
    print(f"{group}: {mu:.2f} [{lb:.2f}, {ub:.2f}]")


results = data.groupby("subgroup").apply(calc_ratio)

for group, (mu, lb, ub) in results.iteritems():
    format_result(group, mu, lb, ub)

mu, lb, ub = calc_ratio(data)
format_result("Overall", mu, lb, ub)
# Out:
# Brace: 0.66 [0.32, 1.35]
# Exercise is too small.
# Foot orthosis: 0.57 [0.42, 0.77]
# Manual therapy: 0.25 [0.16, 0.38]
# Multimodal physiotherapy is too small.
# Taping: 0.66 [0.53, 0.81]
# Overall: 0.53 [0.43, 0.64]

# %%
data.groupby("subgroup").apply(len)
# Out:
# subgroup
# Brace                        4
# Exercise                     1
# Foot orthosis               13
# Manual therapy               4
# Multimodal physiotherapy     2
# Taping                      12
# dtype: int64
